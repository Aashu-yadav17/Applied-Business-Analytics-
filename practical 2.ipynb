# %%
import pandas as pd

# %%
# Load dataset
df = pd.read_csv("startup_funding.csv")
# Display first 5 rows
print(df.head())
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
# Display column names
print(df.columns)
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'Remarks'],
#       dtype='str')

# %%
print("Mean:", funding.mean())
print("Median:", funding.median())
print("Mode:", funding.mode()[0])
print("Variance:", funding.var())
print("Standard Deviation:", funding.std())
print("Minimum:", funding.min())
print("Maximum:", funding.max())
print("Range:", funding.max() - funding.min())
# Out:
# Mean: 18429897.27080872
# Median: 1700000.0
# Mode: 1000000.0
# Variance: 1.4731512939394288e+16
# Standard Deviation: 121373444.12759444
# Minimum: 16000.0
# Maximum: 3900000000.0
# Range: 3899984000.0

# %%
#2b
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.hist(funding, bins=30, edgecolor='black')
plt.title("Histogram of Startup Funding Amount")
plt.xlabel("Amount in USD")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.boxplot(funding, vert=False)
plt.title("Box Plot of Startup Funding Amount")
plt.xlabel("Amount in USD")
plt.show()
# Out:
# C:\Users\itlab\AppData\Local\Temp\ipykernel_12656\1781115534.py:3: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(funding, vert=False)
